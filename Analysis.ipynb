# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
front_page_data = pd.read_csv('alltables.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23430/3827162465.py in <module>
# ----> 1 front_page_data = pd.read_csv('alltables.csv')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23430/1583453580.py in <module>
# ----> 1 front_page_data = pd.read_csv('Alltables.csv')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#    Summary data on annual food imports value and volume by food category and source country 1999-2017  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                          Total U.S. food imports 1/
# 4                                                 NaN
# 5                                   Live meat animals
# 6                                               Meats
# 7                               Fish and shellfish 2/
# 8                                               Dairy
# 9                                          Vegetables
# 10                                             Fruits
# 11                                               Nuts
# 12                            Coffee, tea, and spices
# 13                                             Grains
# 14                                     Vegetable oils
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#    Summary data on annual food imports value and volume by food category and source country 1999-2017  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                          Total U.S. food imports 1/
# 4                                                 NaN
# 5                                   Live meat animals
# 6                                               Meats
# 7                               Fish and shellfish 2/
# 8                                               Dairy
# 9                                          Vegetables
# 10                                             Fruits
# 11                                               Nuts
# 12                            Coffee, tea, and spices
# 13                                             Grains
# 14                                     Vegetable oils
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#    Summary data on annual food imports value and volume by food category and source country 1999-2017  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                          Total U.S. food imports 1/
# 4                                                 NaN
# 5                                   Live meat animals
# 6                                               Meats
# 7                               Fish and shellfish 2/
# 8                                               Dairy
# 9                                          Vegetables
# 10                                             Fruits
# 11                                               Nuts
# 12                            Coffee, tea, and spices
# 13                                             Grains
# 14                                     Vegetable oils
# ...
