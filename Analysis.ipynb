# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
front_page_data = pd.read_csv('alltables.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_6988/3827162465.py in <module>
# ----> 1 front_page_data = pd.read_csv('alltables.csv')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23430/1583453580.py in <module>
# ----> 1 front_page_data = pd.read_csv('Alltables.csv')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#    Summary data on annual food imports value and volume by food category and source country 1999-2017  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                          Total U.S. food imports 1/
# 4                                                 NaN
# 5                                   Live meat animals
# 6                                               Meats
# 7                               Fish and shellfish 2/
# 8                                               Dairy
# 9                                          Vegetables
# 10                                             Fruits
# 11                                               Nuts
# 12                            Coffee, tea, and spices
# 13                                             Grains
# 14                                     Vegetable oils
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#    Summary data on annual food imports value and volume by food category and source country 1999-2017  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                          Total U.S. food imports 1/
# 4                                                 NaN
# 5                                   Live meat animals
# 6                                               Meats
# 7                               Fish and shellfish 2/
# 8                                               Dairy
# 9                                          Vegetables
# 10                                             Fruits
# 11                                               Nuts
# 12                            Coffee, tea, and spices
# 13                                             Grains
# 14                                     Vegetable oils
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#    Summary data on annual food imports value and volume by food category and source country 1999-2017  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                          Total U.S. food imports 1/
# 4                                                 NaN
# 5                                   Live meat animals
# 6                                               Meats
# 7                               Fish and shellfish 2/
# 8                                               Dairy
# 9                                          Vegetables
# 10                                             Fruits
# 11                                               Nuts
# 12                            Coffee, tea, and spices
# 13                                             Grains
# 14                                     Vegetable oils
# ...

# %%
type(front_page_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3613/3499395167.py in <module>
# ----> 1 type(front_page_data)
#
# NameError: name 'front_page_data' is not defined

# %%
front_page_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3613/1251836374.py in <module>
# ----> 1 front_page_data
#
# NameError: name 'front_page_data' is not defined

# %%
clear

# %%
clear all

# %%
front_page_data = pd.read_csv('Alltables.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3613/1583453580.py in <module>
# ----> 1 front_page_data = pd.read_csv('Alltables.csv')
#
# NameError: name 'pd' is not defined

# %%
front_page_data = pd.read_csv('Alltables.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6300/1583453580.py in <module>
# ----> 1 front_page_data = pd.read_csv('Alltables.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#                  Unnamed: 0    1999    2000    2001    2002     2003     2004  \
# 0         Live meat animals  1189.7  1419.0  1771.2  1723.9   1276.7   1134.3
# 1                     Meats  3260.5  3827.7  4256.2  4283.5   4426.8   5718.5
# 2     Fish and shellfish 2/  8859.8  9879.8  9663.3  9963.3  10859.9  11106.3
# 3                     Dairy   930.3   922.3   995.8  1008.8   1110.3   1292.3
# 4                Vegetables  3631.6  3771.4  4156.6  4391.1   5082.4   5730.0
# 5                    Fruits  4764.5  4629.5  4665.2  5067.6   5557.7   5962.4
# 6                      Nuts   793.9   808.7   670.2   700.5    775.6   1078.4
# 7   Coffee, tea, and spices  3603.7  3441.8  2400.7  2455.0   2871.9   3144.3
# 8                    Grains  2659.5  2734.8  2989.8  3342.8   3618.2   4010.5
# 9            Vegetable oils  1356.9  1362.5  1177.0  1301.6   1506.5   2241.0
# 10          Sugar and candy  1617.7  1571.6  1580.9  1842.6   2130.8   2111.3
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#       1999    2000    2001    2002     2003     2004     2005     2006  \
# 0   1189.7  1419.0  1771.2  1723.9   1276.7   1134.3   1672.0   2172.0
# 1   3260.5  3827.7  4256.2  4283.5   4426.8   5718.5   5751.9   5243.6
# 2   8859.8  9879.8  9663.3  9963.3  10859.9  11106.3  11840.2  13112.3
# 3    930.3   922.3   995.8  1008.8   1110.3   1292.3   1388.4   1405.7
# 4   3631.6  3771.4  4156.6  4391.1   5082.4   5730.0   6043.1   6619.3
# 5   4764.5  4629.5  4665.2  5067.6   5557.7   5962.4   6873.8   7707.1
# 6    793.9   808.7   670.2   700.5    775.6   1078.4   1121.9   1099.4
# 7   3603.7  3441.8  2400.7  2455.0   2871.9   3144.3   3770.8   4194.9
# 8   2659.5  2734.8  2989.8  3342.8   3618.2   4010.5   4240.7   4910.1
# 9   1356.9  1362.5  1177.0  1301.6   1506.5   2241.0   2362.6   2818.3
# 10  1617.7  1571.6  1580.9  1842.6   2130.8   2111.3   2473.7   3021.2
# 11  1522.5  1404.5  1535.9  1760.9   2439.2   2484.4   2750.6   2659.2
# ...

# %%
plt.plot(front_page_data.0)
# Out:
#   File "/tmp/ipykernel_6300/1440766648.py", line 1
#     plt.plot(front_page_data.0)
#                             ^
# SyntaxError: invalid syntax

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#    Unnamed: 0    1999    2000    2001    2002     2003     2004     2005  \
# 0       Row 1  1189.7  1419.0  1771.2  1723.9   1276.7   1134.3   1672.0
# 1       Row 2  3260.5  3827.7  4256.2  4283.5   4426.8   5718.5   5751.9
# 2       Row 3  8859.8  9879.8  9663.3  9963.3  10859.9  11106.3  11840.2
# 3       Row 4   930.3   922.3   995.8  1008.8   1110.3   1292.3   1388.4
# 4       Row 5  3631.6  3771.4  4156.6  4391.1   5082.4   5730.0   6043.1
# 5       Row 6  4764.5  4629.5  4665.2  5067.6   5557.7   5962.4   6873.8
# 6       Row 7   793.9   808.7   670.2   700.5    775.6   1078.4   1121.9
# 7       Row 8  3603.7  3441.8  2400.7  2455.0   2871.9   3144.3   3770.8
# 8       Row 9  2659.5  2734.8  2989.8  3342.8   3618.2   4010.5   4240.7
# 9      Row 10  1356.9  1362.5  1177.0  1301.6   1506.5   2241.0   2362.6
# 10     Row 11  1617.7  1571.6  1580.9  1842.6   2130.8   2111.3   2473.7
# 11     Row 12  1522.5  1404.5  1535.9  1760.9   2439.2   2484.4   2750.6
# ...

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data
# Out:
#     1189.7    1419  1771.2  1723.9   1276.7   1134.3     1672     2172  \
# 0   3260.5  3827.7  4256.2  4283.5   4426.8   5718.5   5751.9   5243.6
# 1   8859.8  9879.8  9663.3  9963.3  10859.9  11106.3  11840.2  13112.3
# 2    930.3   922.3   995.8  1008.8   1110.3   1292.3   1388.4   1405.7
# 12     2121.5     2101.7     2252.0     2482.0     3637.2     4784.4
# ...

# %%
front_page_data.Year_1999
# Out:
# 0     1189.7
# 1     3260.5
# 2     8859.8
# 3      930.3
# 4     3631.6
# 5     4764.5
# 6      793.9
# 7     3603.7
# 8     2659.5
# 9     1356.9
# 10    1617.7
# 11    1522.5
# 12    2121.5
# 13    4411.8
# 14    2381.9
# Name: Year_1999, dtype: float64

# %%
front_page_data = pd.read_csv('Alltables.csv')
front_page_data
# Out:
#                  Unnamed: 0  Year_1999  Year_2000  Year_2001  Year_2002  \
# 0         Live meat animals     1189.7     1419.0     1771.2     1723.9
# 1                     Meats     3260.5     3827.7     4256.2     4283.5
# 2     Fish and shellfish 2/     8859.8     9879.8     9663.3     9963.3
# 3                     Dairy      930.3      922.3      995.8     1008.8
# 4                Vegetables     3631.6     3771.4     4156.6     4391.1
# 5                    Fruits     4764.5     4629.5     4665.2     5067.6
# 6                      Nuts      793.9      808.7      670.2      700.5
# 7   Coffee, tea, and spices     3603.7     3441.8     2400.7     2455.0
# 8                    Grains     2659.5     2734.8     2989.8     3342.8
# 9            Vegetable oils     1356.9     1362.5     1177.0     1301.6
# 10          Sugar and candy     1617.7     1571.6     1580.9     1842.6
# 11      Cocoa and chocolate     1522.5     1404.5     1535.9     1760.9
# ...

# %%
front_page_data.Vegetables
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6300/1922343554.py in <module>
# ----> 1 front_page_data.Vegetables
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Vegetables'

# %%
front_page_data.2
# Out:
#   File "/tmp/ipykernel_6300/1499040004.py", line 1
#     front_page_data.2
#                    ^
# SyntaxError: invalid syntax

# %%
front_page_data = pd.read_csv('Alltables.csv')
front_page_data
# Out:
#               Product_name  Year_1999  Year_2000  Year_2001  Year_2002  \
# 0        Live_meat_animals     1189.7     1419.0     1771.2     1723.9
# 1                    Meats     3260.5     3827.7     4256.2     4283.5
# 2       Fish_and_shellfish     8859.8     9879.8     9663.3     9963.3
# 3                    Dairy      930.3      922.3      995.8     1008.8
# 4               Vegetables     3631.6     3771.4     4156.6     4391.1
# 5                   Fruits     4764.5     4629.5     4665.2     5067.6
# 6                     Nuts      793.9      808.7      670.2      700.5
# 7   Coffee_tea_ and_spices     3603.7     3441.8     2400.7     2455.0
# 8                   Grains     2659.5     2734.8     2989.8     3342.8
# 9           Vegetable_oils     1356.9     1362.5     1177.0     1301.6
# 10         Sugar_and_candy     1617.7     1571.6     1580.9     1842.6
# 11     Cocoa_and_chocolate     1522.5     1404.5     1535.9     1760.9
# ...

# %%
front_page_data.Product_name == Meats
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6300/1620976873.py in <module>
# ----> 1 front_page_data.Product_name == Meats
#
# NameError: name 'Meats' is not defined

# %%
front_page_data.Product_name == 'Meats'
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: Product_name, dtype: bool

# %%
front_page_data = pd.read_csv('Alltables.csv')
front_page_data
# Out:
#     Year  Live_meat_animals   Meats  Fish_and_shellfish   Dairy  Vegetables  \
# 0   1999             1189.7  3260.5              8859.8   930.3      3631.6
# 1   2000             1419.0  3827.7              9879.8   922.3      3771.4
# 2   2001             1771.2  4256.2              9663.3   995.8      4156.6
# 3   2002             1723.9  4283.5              9963.3  1008.8      4391.1
# 4   2003             1276.7  4426.8             10859.9  1110.3      5082.4
# 5   2004             1134.3  5718.5             11106.3  1292.3      5730.0
# 6   2005             1672.0  5751.9             11840.2  1388.4      6043.1
# 7   2006             2172.0  5243.6             13112.3  1405.7      6619.3
# 8   2007             2588.0  5367.3             13434.6  1500.8      7256.0
# 9   2008             2266.4  5059.8             13912.0  1595.6      7800.6
# 10  2009             1655.5  4612.1             12933.9  1353.4      7525.2
# ...

# %%
front_page_data.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6300/1086509790.py in <module>
# ----> 1 front_page_data.year
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'year'

# %%
front_page_data.Year
# Out:
# 0     1999
# 1     2000
# 2     2001
# 3     2002
# 4     2003
# 5     2004
# 6     2005
# 7     2006
# 8     2007
# 9     2008
# 10    2009
# 11    2010
# 12    2011
# 13    2012
# 14    2013
# 15    2014
# 16    2015
# 17    2016
# 18    2017
# Name: Year, dtype: int64

# %%
plt.plot(front_page_data.Year, front_page_data.Live_meat_animals)
plt.plot(front_page_data.Year, front_page_data.Meats)
plt.plot(front_page_data.Year, front_page_data.Fish_and_shellfish)
plt.plot(front_page_data.Year, front_page_data.Dairy)
plt.plot(front_page_data.Year, front_page_data.Vegetables)
plt.plot(front_page_data.Year, front_page_data.Fruits)
plt.plot(front_page_data.Year, front_page_data.Nuts)
# plt.plot(front_page_data.Year, front_page_data.Coffee_tea_and_spices)
plt.plot(front_page_data.Year, front_page_data.Grains)
plt.plot(front_page_data.Year, front_page_data.Vegetable_oils)
plt.plot(front_page_data.Year, front_page_data.Sugar_and_candy)
plt.plot(front_page_data.Year, front_page_data.Cocoa_and_chocolate)
plt.plot(front_page_data.Year, front_page_data.Other_edibles)
plt.plot(front_page_data.Year, front_page_data.Beverages)
plt.plot(front_page_data.Year, front_page_data.Liquors)

# %%
front_page_data = pd.read_csv('Alltables.csv')

# %%
front_page_data.describe()
# Out:
#               Year  Live_meat_animals        Meats  Fish_and_shellfish  \
# count    19.000000          19.000000    19.000000           19.000000
# mean   2008.000000        1949.921053  5885.510526        14208.021053
# std       5.627314         512.685172  1902.583692         3858.273297
# min    1999.000000        1134.300000  3260.500000         8859.800000
# 25%    2003.500000        1663.750000  4519.450000        10983.100000
# 50%    2008.000000        2007.100000  5367.300000        13434.600000
# 75%    2012.500000        2191.100000  6387.500000        17125.900000
# max    2017.000000        3008.600000  9991.700000        21324.100000
#
#              Dairy    Vegetables        Fruits         Nuts  \
# count    19.000000     19.000000     19.000000    19.000000
# mean   1423.531579   7815.300000   9949.415789  1551.731579
# std     322.126994   2988.335352   4500.760486   800.459150
# min     922.300000   3631.600000   4629.500000   670.200000
# ...

# %%
import numpy as np

# %%
myArray = np.array([1,2,3,4,5,6,7,8])

# %%
myArray[0]
# Out:
# 1

# %%
myArray[:8]
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
myArray[0:]
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %% [markdown]
# myArray[1:3]

# %%
myArray[1:3]
# Out:
# array([2, 3])

# %%
myArray[0:7]
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
myArray[1:-1]
# Out:
# array([2, 3, 4, 5, 6, 7])

# %%
myArray[2:-2]
# Out:
# array([3, 4, 5, 6])

# %%
myArray[::2]
# Out:
# array([1, 3, 5, 7])

# %%
myArray[-1]
# Out:
# 8

# %%
myArray[-2]
# Out:
# 7
